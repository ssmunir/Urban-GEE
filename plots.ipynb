# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
# Define the folder containing the CSV files
main_path = r"C:\Users\auuser\Documents\Munir\Urbanization Analysis\GEE\Data"
folder_path = main_path + r"\Population data"
results = main_path + r"\Results"

# %%
dt = pd.read_csv(results + r"\full_population_data.csv")

# %%
del dt["Unnamed: 0"]
dt.head(2)
# Out:
#        country continent  Population2000  Population2010  Population2020  \
# 0        Abyei         0           11023           13882           29840
# 1  Afghanistan      Asia        23755401        34231732        47316798
#
#    Population2030  UrbanPopulation_10YearLag2000  \
# 0           34175                              0
# 1        61092584                        3399671
#
#    UrbanPopulation_10YearLag2010  UrbanPopulation_10YearLag2020  \
# 0                           4773                           4756
# 1                        3192048                        4659915
#
#    UrbanPopulation_10YearLag2030  UrbanPopulation_20YearLag2000  \
# 0                           2992                              0
# 1                        4063225                        3112414
#
#    UrbanPopulation_20YearLag2010  UrbanPopulation_20YearLag2020  \
# 0                           4773                           9964
# 1                        6878606                        8326605
#
#    UrbanPopulation_20YearLag2030  UrbanPopulation2000  UrbanPopulation2010  \
# 0                           6644                    0                 4773
# 1                        9333588             13735834             21183709
#
#    UrbanPopulation2020  UrbanPopulation2030      Region Income group
# 0                 9964                12009         NaN          NaN
# 1             32273966             45229174  South Asia   Low income

# %%
### define plot variables
dt["popChange"] = dt["Population2020"] - dt["Population2010"]
dt["urbanPopChange"] = dt["UrbanPopulation2020"] - dt["UrbanPopulation2010"]
dt["shOfUrbanPopChange"] = dt["UrbanPopulation_10YearLag2020"]/dt["urbanPopChange"]
dt["shareUrbanPop2010"] = dt["UrbanPopulation2010"]/dt["Population2010"]
dt["urbanGrowthRate"] = dt["urbanPopChange"]/dt["UrbanPopulation2010"]

# %%
# Plot 1
plt.figure(figsize=(8, 4))

sns.scatterplot(data=dt, x="urbanGrowthRate", y="shOfUrbanPopChange", hue="Region")
plt.xlabel("Urban Growth Rate")
plt.ylabel("Share of Population Change on Periphery")
plt.title("2010/2020 Figures")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', title="Region \n")
plt.tight_layout()
plt.savefig(results + r"\plot1.png")
plt.show()

# %%
# Plot 2
plt.figure(figsize=(8, 4))

sns.scatterplot(data=dt, x="shareUrbanPop2010", y="shOfUrbanPopChange", hue="Region")
plt.xlabel("Share of Population that is Urban in 2010")
plt.ylabel("Share of Population Change on Periphery")
plt.title("2010/2020 Figures")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', title="Region \n")
plt.tight_layout()
plt.savefig(results + r"\plot2.png")
plt.show()

# %%
plt.figure(figsize=(8, 4))

sns.scatterplot(data=dt, x="urbanGrowthRate", y="shareUrbanPop2010", hue="Region")
plt.xlabel("Urban Growth Rate")
plt.ylabel("Share of Population that is Urban in 2010")
plt.title("2010/2020 Figures")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', title="Region \n")
plt.tight_layout()
plt.savefig(results + r"\plot3.png")
plt.show()
